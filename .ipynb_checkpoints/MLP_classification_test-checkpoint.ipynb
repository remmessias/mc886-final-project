# %%
import numpy as np
import pandas as pd
import tensorflow as tf
tf.enable_eager_execution()

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('features.csv')
df
# Out:
#      Ano                 Presidente      Partido    Pop_Total  Desemprego  \
# 0   2000  Fernando Henrique Cardoso         PSDB          NaN         NaN
# 1   2001  Fernando Henrique Cardoso         PSDB          NaN         NaN
# 2   2002  Fernando Henrique Cardoso         PSDB          NaN         NaN
# 3   2003  Fernando Henrique Cardoso         PSDB          NaN         NaN
# 4   2004  Luiz Inácio Lula da Silva           PT          NaN         NaN
# 5   2005  Luiz Inácio Lula da Silva           PT          NaN         NaN
# 6   2006  Luiz Inácio Lula da Silva           PT          NaN         NaN
# 7   2007  Luiz Inácio Lula da Silva           PT          NaN         NaN
# 8   2008  Luiz Inácio Lula da Silva           PT          NaN         NaN
# 9   2009  Luiz Inácio Lula da Silva           PT          NaN         NaN
# 10  2010  Luiz Inácio Lula da Silva           PT          NaN         NaN
# 11  2011  Luiz Inácio Lula da Silva           PT          NaN         NaN
# 12  2012             Dilma Rousseff           PT  198360000.0   6611000.0
# 13  2013             Dilma Rousseff           PT  200074000.0   6013000.0
# 14  2014             Dilma Rousseff           PT  201783000.0   6409000.0
# 15  2015             Dilma Rousseff           PT  203482000.0   9019000.0
# 16  2016             Dilma Rousseff           PT  205165000.0  12278000.0
# 17  2017               Michel Temer         PMDB  206829000.0  12267000.0
# 18  2018               Michel Temer         PMDB  208468000.0  12152000.0
# 19  2019             Jair Bolsonaro          PSL  210077000.0  11632000.0
# 20  2020             Jair Bolsonaro  Sem partido  211652000.0  13925000.0
#
#     TFEB_Total  TFEB_0_3  TFEB_4_5  TFEB_6_10  TFEB_11_14  ...  TA15M_M  \
# 0          NaN       NaN       NaN        NaN         NaN  ...      NaN
# 1          NaN       NaN       NaN        NaN         NaN  ...      NaN
# 2          NaN       NaN       NaN        NaN         NaN  ...      NaN
# 3          NaN       NaN       NaN        NaN         NaN  ...      NaN
# 4         31.7      13.4      61.5       95.9        96.4  ...     11.3
# 5         31.2      13.0      62.8       96.4        96.7  ...     10.9
# 6         31.2      15.4      67.5       96.9        96.9  ...     10.2
# 7         30.7      17.0      70.0       97.0        97.0  ...      9.9
# 8         30.2      18.1      72.7       97.6        97.3  ...      9.8
# 9         29.8      18.4      74.8       97.7        97.5  ...      9.6
# 10         NaN       NaN       NaN        NaN         NaN  ...      NaN
# 11        28.6      20.8      77.4       98.3        98.1  ...      8.4
# 12        28.0      21.2      78.1       98.3        98.1  ...      8.4
# 13        27.9      23.2      81.4       98.7        98.2  ...      8.2
# 14        27.2      24.6      82.7       98.8        98.2  ...      7.9
# 15        26.8      25.6      84.3       98.9        98.3  ...      7.7
# 16        27.5      30.4      90.2       99.5        98.9  ...      7.0
# 17        27.3      32.7      91.7       99.3        99.1  ...      6.8
# 18        27.1      34.2      92.4       99.6        99.1  ...      NaN
# 19        26.9      35.6      92.9       99.8        99.5  ...      NaN
# 20         NaN       NaN       NaN        NaN         NaN  ...      NaN
#
#     TA15M_Bra  TA15M_Pre_Par  TA15M_GI_15_19  TA15M_GI_20_24  TA15M_GI_25_34  \
# 0         NaN            NaN             NaN             NaN             NaN
# 1         NaN            NaN             NaN             NaN             NaN
# 2         NaN            NaN             NaN             NaN             NaN
# 3         NaN            NaN             NaN             NaN             NaN
# 4         7.2           16.3             2.4             4.0             6.6
# 5         7.0           15.5             2.3             3.5             6.4
# 6         6.5           14.7             1.8             3.1             5.6
# 7         6.2           14.2             1.8             2.7             5.2
# 8         6.2           13.7             1.8             2.6             5.1
# 9         5.9           13.4             1.5             2.4             4.6
# 10        NaN            NaN             NaN             NaN             NaN
# 11        5.3           11.8             1.2             1.8             3.7
# 12        5.3           11.8             1.2             1.6             3.5
# 13        5.2           11.5             1.0             1.6             3.2
# 14        5.0           11.1             0.9             1.4             2.8
# 15        4.9           10.6             0.8             1.3             2.5
# 16        4.2            9.9             0.7             1.1             2.1
# 17        4.0            9.3             0.6             1.1             1.9
# 18        NaN            NaN             NaN             NaN             NaN
# 19        NaN            NaN             NaN             NaN             NaN
# 20        NaN            NaN             NaN             NaN             NaN
#
#     TA15M_GI_35_44  TA15M_GI_45_54  TA15M_GI_55_64  TA15M_GI_65_M
# 0              NaN             NaN             NaN            NaN
# 1              NaN             NaN             NaN            NaN
# 2              NaN             NaN             NaN            NaN
# 3              NaN             NaN             NaN            NaN
# 4              9.6            14.0            23.5           34.4
# 5              9.3            13.2            22.6           33.8
# 6              8.7            12.7            20.8           32.1
# 7              8.3            11.9            19.8           31.3
# 8              8.1            11.1            19.0           30.8
# 9              7.9            10.8            17.9           30.8
# 10             NaN             NaN             NaN            NaN
# 11             6.6             9.5            15.2           28.0
# 12             6.6             9.8            15.7           27.2
# 13             6.3             9.3            14.8           27.7
# 14             6.0             9.4            13.8           26.4
# 15             5.5             8.6            12.9           25.7
# 16             4.8             7.9            11.9           23.5
# 17             4.6             7.7            11.4           22.3
# 18             NaN             NaN             NaN            NaN
# 19             NaN             NaN             NaN            NaN
# 20             NaN             NaN             NaN            NaN
#
# [21 rows x 35 columns]

# %%
X = df.iloc[1:, 5:]
y = pd.DataFrame(np.random.rand(len(X)))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(X)
print(X_train.shape)
print(y_train.shape)
# Out:
#     TFEB_Total  TFEB_0_3  TFEB_4_5  TFEB_6_10  TFEB_11_14  TFEB_6_14  \
# 1          NaN       NaN       NaN        NaN         NaN        NaN
# 2          NaN       NaN       NaN        NaN         NaN        NaN
# 3          NaN       NaN       NaN        NaN         NaN        NaN
# 4         31.7      13.4      61.5       95.9        96.4       96.1
# 5         31.2      13.0      62.8       96.4        96.7       96.5
# 6         31.2      15.4      67.5       96.9        96.9       96.9
# 7         30.7      17.0      70.0       97.0        97.0       97.0
# 8         30.2      18.1      72.7       97.6        97.3       97.5
# 9         29.8      18.4      74.8       97.7        97.5       97.6
# 10         NaN       NaN       NaN        NaN         NaN        NaN
# 11        28.6      20.8      77.4       98.3        98.1       98.2
# 12        28.0      21.2      78.1       98.3        98.1       98.2
# 13        27.9      23.2      81.4       98.7        98.2       98.4
# 14        27.2      24.6      82.7       98.8        98.2       98.5
# 15        26.8      25.6      84.3       98.9        98.3       98.6
# 16        27.5      30.4      90.2       99.5        98.9       99.2
# 17        27.3      32.7      91.7       99.3        99.1       99.2
# 18        27.1      34.2      92.4       99.6        99.1       99.3
# 19        26.9      35.6      92.9       99.8        99.5       99.7
# 20         NaN       NaN       NaN        NaN         NaN        NaN
#
#     TFEB_15_17  TFEB_18_24  TFEB_25_Mais  NI25M_Sem  ...  TA15M_M  TA15M_Bra  \
# 1          NaN         NaN           NaN        NaN  ...      NaN        NaN
# 2          NaN         NaN           NaN        NaN  ...      NaN        NaN
# 3          NaN         NaN           NaN        NaN  ...      NaN        NaN
# 4         81.8        32.2           5.6        NaN  ...     11.3        7.2
# 5         81.6        31.6           5.7        NaN  ...     10.9        7.0
# 6         82.1        31.7           5.6        NaN  ...     10.2        6.5
# 7         82.1        30.8           5.5        NaN  ...      9.9        6.2
# 8         84.1        30.4           5.3        NaN  ...      9.8        6.2
# 9         85.2        30.3           5.1        NaN  ...      9.6        5.9
# 10         NaN         NaN           NaN        NaN  ...      NaN        NaN
# 11        83.7        28.9           4.5        NaN  ...      8.4        5.3
# 12        84.2        29.3           4.1        NaN  ...      8.4        5.3
# 13        84.3        30.0           4.1        NaN  ...      8.2        5.2
# 14        84.3        30.0           4.0        NaN  ...      7.9        5.0
# 15        85.0        30.7           3.7        NaN  ...      7.7        4.9
# 16        87.2        32.8           4.2        7.8  ...      7.0        4.2
# 17        87.2        31.7           4.3        7.2  ...      6.8        4.0
# 18        88.2        32.7           4.6        NaN  ...      NaN        NaN
# 19        89.2        32.4           4.5        NaN  ...      NaN        NaN
# 20         NaN         NaN           NaN        NaN  ...      NaN        NaN
#
#     TA15M_Pre_Par  TA15M_GI_15_19  TA15M_GI_20_24  TA15M_GI_25_34  \
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4            16.3             2.4             4.0             6.6
# 5            15.5             2.3             3.5             6.4
# 6            14.7             1.8             3.1             5.6
# 7            14.2             1.8             2.7             5.2
# 8            13.7             1.8             2.6             5.1
# 9            13.4             1.5             2.4             4.6
# 10            NaN             NaN             NaN             NaN
# 11           11.8             1.2             1.8             3.7
# 12           11.8             1.2             1.6             3.5
# 13           11.5             1.0             1.6             3.2
# 14           11.1             0.9             1.4             2.8
# 15           10.6             0.8             1.3             2.5
# 16            9.9             0.7             1.1             2.1
# 17            9.3             0.6             1.1             1.9
# 18            NaN             NaN             NaN             NaN
# 19            NaN             NaN             NaN             NaN
# 20            NaN             NaN             NaN             NaN
#
#     TA15M_GI_35_44  TA15M_GI_45_54  TA15M_GI_55_64  TA15M_GI_65_M
# 1              NaN             NaN             NaN            NaN
# 2              NaN             NaN             NaN            NaN
# 3              NaN             NaN             NaN            NaN
# 4              9.6            14.0            23.5           34.4
# 5              9.3            13.2            22.6           33.8
# 6              8.7            12.7            20.8           32.1
# 7              8.3            11.9            19.8           31.3
# 8              8.1            11.1            19.0           30.8
# 9              7.9            10.8            17.9           30.8
# 10             NaN             NaN             NaN            NaN
# 11             6.6             9.5            15.2           28.0
# 12             6.6             9.8            15.7           27.2
# 13             6.3             9.3            14.8           27.7
# 14             6.0             9.4            13.8           26.4
# 15             5.5             8.6            12.9           25.7
# 16             4.8             7.9            11.9           23.5
# 17             4.6             7.7            11.4           22.3
# 18             NaN             NaN             NaN            NaN
# 19             NaN             NaN             NaN            NaN
# 20             NaN             NaN             NaN            NaN
#
# [20 rows x 30 columns]
# (16, 30)
# (16, 1)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(30,)),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 16/16 [==============================] - 0s 3ms/sample - loss: nan - acc: 0.0000e+00
# Epoch 2/5
# 16/16 [==============================] - 0s 77us/sample - loss: nan - acc: 0.0000e+00
# Epoch 3/5
# 16/16 [==============================] - 0s 69us/sample - loss: nan - acc: 0.0000e+00
# Epoch 4/5
# 16/16 [==============================] - 0s 65us/sample - loss: nan - acc: 0.0000e+00
# Epoch 5/5
# 16/16 [==============================] - 0s 60us/sample - loss: nan - acc: 0.0000e+00

# %%
model.evaluate(X_test,  y_test, verbose=2)
# Out:
# 4/4 - 0s - loss: nan - acc: 0.0000e+00
# [nan, 0.0]
